# %% [markdown]
# ### 2951. Find the Peaks
#
# Problem link: https://leetcode.com/problems/find-the-peaks/

# %% [markdown]
# **Code**

# %%
class Solution:
    def findPeaks(self, mountain: List[int]) -> List[int]:

        result = []
        first_element =0
        last_element = len(mountain)-1

        for i in range(len(mountain)):
            if i ==first_element or i ==last_element:
                continue
            else:
                prev= i-1
                next= i+1
                if  (mountain[prev] < mountain[i]) and (mountain[next] < mountain[i]):
                    result.append(i)
        return result

# %% [markdown]
# ## **Time and Space Complexity Analysis**
#
# #### 🔹 Step-by-step complexity analysis
#
# 1. **`result = []`** → Creates an empty list → **O(1)**
# 2. **`first_element = 0`** → Variable assignment → **O(1)**
# 3. **`last_element = len(mountain) - 1`**
#
#    * `len(mountain)` is **O(1)** in Python
#    * Subtraction and assignment → **O(1)**
#
#
# ##### Inside the loop `for i in range(len(mountain)):`
#
# * `len(mountain)` is **O(1)**.
# * `range(n)` creates an iterator in **O(1)**.
# * Loop runs **n times**, so cost will be multiplied by `n`.
#
# Now inside the loop:
#
# 4. **`if i == first_element or i == last_element:`**
#
#    * Comparison `i == first_element` → **O(1)**
#    * Comparison `i == last_element` → **O(1)**
#    * Boolean OR → **O(1)**
#
#    → Total: **O(1)**
#
# 5. **`continue` (when true)** → Just moves to next iteration → **O(1)**
#
#
# Else branch (executed for indices `1` to `n-2`):
#
# 6. **`prev = i - 1`** → Arithmetic + assignment → **O(1)**
#
# 7. **`next = i + 1`** → Arithmetic + assignment → **O(1)**
#
# 8. **Condition check:**
#
#    ```python
#    if (mountain[prev] < mountain[i]) and (mountain[next] < mountain[i]):
#    ```
#
#    * `mountain[prev]` → Indexing → **O(1)**
#    * `mountain[i]` → Indexing → **O(1)**
#    * Comparison `<` → **O(1)**
#    * `mountain[next]` → Indexing → **O(1)**
#    * `mountain[i]` (already accessed, but Python will fetch again) → **O(1)**
#    * Comparison `<` → **O(1)**
#    * Logical `and` → **O(1)**
#
#    → Total: **O(1)**
#
# 9. **`result.append(i)`** (if condition passes)
#
#    * Append to list in Python (amortized) → **O(1)**
#
#
# #### Final Step:
#
# 10. **`return result`** → Returning reference to list → **O(1)**
#
#
# ####  Overall Complexity
#
# * Each loop iteration = constant work = **O(1)**
# * Loop runs **n times** → **O(n)**
# * Output list storage = **O(k)** where `k` = number of peaks, worst case `O(n)`
#
# ✅ **Time Complexity:** O(n)
#
# ✅ **Space Complexity:** O(n) (result list), O(1) extra for variables

# %% [markdown]
# ### **Takeaways**
#
# What is <font color="green">***0-indexed array?***</font>
#
# A "**0-indexed array**" refers to an array or similar data structure where the *first element* is accessed using the ***index 0***, the second element using the index 1, and so on. This is in contrast to "**1-indexed**" systems where the first element is accessed with index 1.
#
# Key characteristics of 0-indexed arrays:
#
# - **Starting Index:** The index of the very first element is 0.
#     Subsequent Elements: Each subsequent element's index increments by one from the previous, meaning the n-th element is found at index n-1.
#
# - **Common in Programming:** Most modern programming languages, including C++, Java, Python, JavaScript, and many others, utilize 0-based indexing for arrays and lists.
