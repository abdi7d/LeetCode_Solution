# %% [markdown]
# ### **283.Move Zeros**
#
# Problem Link: https://leetcode.com/problems/move-zeroes/?envType=problem-list-v2&envId=two-pointers

# %% [markdown]
# #### **Hints**
#
# What is **`In-Place`**?
#
# **In-place** means modifying the data **directly in the original memory location**, <font color="green"> without using extra space</font> for another copy of the data.
#
# ##### In simpler terms:
#
# You **don't create a new array or list** — you just update or rearrange the elements in the existing one.
#
# #### Example:
#
# If you're given:
#
# ```python
# nums = [0, 1, 0, 3, 12]
# ```
#
# And your goal is to move the zeroes to the end **in-place**, you change `nums` directly to:
#
# ```python
# [1, 3, 12, 0, 0]
# ```
#
# <font color="green">without </font>doing something like:
#
# ```python
# new_nums = [1, 3, 12, 0, 0]  # ❌ This is not in-place
# ```
#
# ##### Why is it important?
#
# * Saves memory.
# * Often required in coding interviews and competitions.

# %% [markdown]
# #### **Code**

# %%
class Solution:
    def moveZeroes(self, nums: list[int]) -> None:
        # First pointer: Pointer to place the next non-zero element(position to place the next non-zero element)
        last_non_zero = 0

        # Second pointer: scan the list (Move non-zeroes forward)
        for i in range(len(nums)):
            if nums[i] != 0:
                # Swap current non-zero with last_non_zero
                nums[last_non_zero], nums[i] = nums[i], nums[last_non_zero]
                last_non_zero += 1

# %% [markdown]
# **Usage**

# %%
# Example usage:
nums = [0, 1, 0, 3, 12]
Solution().moveZeroes(nums)
print(nums)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### **Time and Space Complexity**
#
# **Time Complexity: `O(n)`**
#
# * We loop through the array **once**, where `n = len(nums)`.
# * Each element is visited **exactly one time**, and **each swap (if any)** is done in constant time.
# * So overall, it's **linear time**.
#
# **Space Complexity: `O(1)`**
#
# * We don’t use any extra space — only a few variables (`i`, `last_non_zero`).
# * The list is modified **in-place**, as required.
